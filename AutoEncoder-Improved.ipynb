# %%
# Load the essential libraries

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from platform import python_version
import tensorflow as tf
from pyod.models.auto_encoder import AutoEncoder
from sklearn.preprocessing import StandardScaler

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

print(f'TensorFlow version: {tf.__version__}')
print(f'Python version: {python_version()}')
# Out:
# 2025-11-22 10:48:32.656283: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-22 10:48:33.250882: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/peera/ros2_ws/install/v4l2_camera/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner_testutils/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner/lib:/home/peera/ws_moveit/install/moveit_visual_tools/lib:/home/peera/ws_moveit/install/moveit_task_constructor_visualization/lib:/home/peera/ws_moveit/install/moveit_task_constructor_demo/lib:/home/peera/ws_moveit/install/moveit_task_constructor_capabilities/lib:/home/peera/ws_moveit/install/moveit_task_constructor_core/lib:/home/peera/ws_moveit/install/moveit_ros_control_interface/lib:/home/peera/ws_moveit/install/moveit_simple_controller_manager/lib:/home/peera/ws_moveit/install/moveit_setup_assistant/lib:/home/peera/ws_moveit/install/moveit_setup_srdf_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_core_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_controllers/lib:/home/peera/ws_moveit/install/moveit_setup_app_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_framework/lib:/home/peera/ws_moveit/install/moveit_servo/lib:/home/peera/ws_moveit/install/moveit_ros_visualization/lib:/home/peera/ws_moveit/install/moveit_hybrid_planning/lib:/home/peera/ws_moveit/install/moveit_ros_planning_interface/lib:/home/peera/ws_moveit/install/moveit_ros_benchmarks/lib:/home/peera/ws_moveit/install/moveit_ros_warehouse/lib:/home/peera/ws_moveit/install/moveit_ros_robot_interaction/lib:/home/peera/ws_moveit/install/moveit_ros_perception/lib:/home/peera/ws_moveit/install/moveit_ros_move_group/lib:/home/peera/ws_moveit/install/moveit_planners_ompl/lib:/home/peera/ws_moveit/install/moveit_ros_planning/lib:/home/peera/ws_moveit/install/moveit_ros_occupancy_map_monitor/lib:/home/peera/ws_moveit/install/moveit_resources_prbt_ikfast_manipulator_plugin/lib:/home/peera/ws_moveit/install/moveit_planners_chomp/lib:/home/peera/ws_moveit/install/moveit_kinematics/lib:/home/peera/ws_moveit/install/moveit_chomp_optimizer_adapter/lib:/home/peera/ws_moveit/install/chomp_motion_planner/lib:/home/peera/ws_moveit/install/moveit_core/lib:/home/peera/ws_moveit/install/srdfdom/lib:/home/peera/ws_moveit/install/rviz_marker_tools/lib:/home/peera/ws_moveit/install/rosparam_shortcuts/lib:/home/peera/ws_moveit/install/moveit_task_constructor_msgs/lib:/home/peera/voidwalking/ros2_ws/install/spatio_temporal_voxel_layer/lib:/home/peera/voidwalking/ros2_ws/install/rviz_satellite/lib:/home/peera/voidwalking/ros2_ws/install/mapping/lib:/usr/lib/x86_64-linux-gnu/gazebo-11/plugins:/opt/ros/humble/opt/rviz_ogre_vendor/lib:/opt/ros/humble/lib/x86_64-linux-gnu:/opt/ros/humble/lib
# 2025-11-22 10:48:33.250929: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-11-22 10:48:35.411182: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/peera/ros2_ws/install/v4l2_camera/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner_testutils/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner/lib:/home/peera/ws_moveit/install/moveit_visual_tools/lib:/home/peera/ws_moveit/install/moveit_task_constructor_visualization/lib:/home/peera/ws_moveit/install/moveit_task_constructor_demo/lib:/home/peera/ws_moveit/install/moveit_task_constructor_capabilities/lib:/home/peera/ws_moveit/install/moveit_task_constructor_core/lib:/home/peera/ws_moveit/install/moveit_ros_control_interface/lib:/home/peera/ws_moveit/install/moveit_simple_controller_manager/lib:/home/peera/ws_moveit/install/moveit_setup_assistant/lib:/home/peera/ws_moveit/install/moveit_setup_srdf_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_core_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_controllers/lib:/home/peera/ws_moveit/install/moveit_setup_app_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_framework/lib:/home/peera/ws_moveit/install/moveit_servo/lib:/home/peera/ws_moveit/install/moveit_ros_visualization/lib:/home/peera/ws_moveit/install/moveit_hybrid_planning/lib:/home/peera/ws_moveit/install/moveit_ros_planning_interface/lib:/home/peera/ws_moveit/install/moveit_ros_benchmarks/lib:/home/peera/ws_moveit/install/moveit_ros_warehouse/lib:/home/peera/ws_moveit/install/moveit_ros_robot_interaction/lib:/home/peera/ws_moveit/install/moveit_ros_perception/lib:/home/peera/ws_moveit/install/moveit_ros_move_group/lib:/home/peera/ws_moveit/install/moveit_planners_ompl/lib:/home/peera/ws_moveit/install/moveit_ros_planning/lib:/home/peera/ws_moveit/install/moveit_ros_occupancy_map_monitor/lib:/home/peera/ws_moveit/install/moveit_resources_prbt_ikfast_manipulator_plugin/lib:/home/peera/ws_moveit/install/moveit_planners_chomp/lib:/home/peera/ws_moveit/install/moveit_kinematics/lib:/home/peera/ws_moveit/install/moveit_chomp_optimizer_adapter/lib:/home/peera/ws_moveit/install/chomp_motion_planner/lib:/home/peera/ws_moveit/install/moveit_core/lib:/home/peera/ws_moveit/install/srdfdom/lib:/home/peera/ws_moveit/install/rviz_marker_tools/lib:/home/peera/ws_moveit/install/rosparam_shortcuts/lib:/home/peera/ws_moveit/install/moveit_task_constructor_msgs/lib:/home/peera/voidwalking/ros2_ws/install/spatio_temporal_voxel_layer/lib:/home/peera/voidwalking/ros2_ws/install/rviz_satellite/lib:/home/peera/voidwalking/ros2_ws/install/mapping/lib:/usr/lib/x86_64-linux-gnu/gazebo-11/plugins:/opt/ros/humble/opt/rviz_ogre_vendor/lib:/opt/ros/humble/lib/x86_64-linux-gnu:/opt/ros/humble/lib
# 2025-11-22 10:48:35.412295: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/peera/ros2_ws/install/v4l2_camera/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner_testutils/lib:/home/peera/ws_moveit/install/pilz_industrial_motion_planner/lib:/home/peera/ws_moveit/install/moveit_visual_tools/lib:/home/peera/ws_moveit/install/moveit_task_constructor_visualization/lib:/home/peera/ws_moveit/install/moveit_task_constructor_demo/lib:/home/peera/ws_moveit/install/moveit_task_constructor_capabilities/lib:/home/peera/ws_moveit/install/moveit_task_constructor_core/lib:/home/peera/ws_moveit/install/moveit_ros_control_interface/lib:/home/peera/ws_moveit/install/moveit_simple_controller_manager/lib:/home/peera/ws_moveit/install/moveit_setup_assistant/lib:/home/peera/ws_moveit/install/moveit_setup_srdf_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_core_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_controllers/lib:/home/peera/ws_moveit/install/moveit_setup_app_plugins/lib:/home/peera/ws_moveit/install/moveit_setup_framework/lib:/home/peera/ws_moveit/install/moveit_servo/lib:/home/peera/ws_moveit/install/moveit_ros_visualization/lib:/home/peera/ws_moveit/install/moveit_hybrid_planning/lib:/home/peera/ws_moveit/install/moveit_ros_planning_interface/lib:/home/peera/ws_moveit/install/moveit_ros_benchmarks/lib:/home/peera/ws_moveit/install/moveit_ros_warehouse/lib:/home/peera/ws_moveit/install/moveit_ros_robot_interaction/lib:/home/peera/ws_moveit/install/moveit_ros_perception/lib:/home/peera/ws_moveit/install/moveit_ros_move_group/lib:/home/peera/ws_moveit/install/moveit_planners_ompl/lib:/home/peera/ws_moveit/install/moveit_ros_planning/lib:/home/peera/ws_moveit/install/moveit_ros_occupancy_map_monitor/lib:/home/peera/ws_moveit/install/moveit_resources_prbt_ikfast_manipulator_plugin/lib:/home/peera/ws_moveit/install/moveit_planners_chomp/lib:/home/peera/ws_moveit/install/moveit_kinematics/lib:/home/peera/ws_moveit/install/moveit_chomp_optimizer_adapter/lib:/home/peera/ws_moveit/install/chomp_motion_planner/lib:/home/peera/ws_moveit/install/moveit_core/lib:/home/peera/ws_moveit/install/srdfdom/lib:/home/peera/ws_moveit/install/rviz_marker_tools/lib:/home/peera/ws_moveit/install/rosparam_shortcuts/lib:/home/peera/ws_moveit/install/moveit_task_constructor_msgs/lib:/home/peera/voidwalking/ros2_ws/install/spatio_temporal_voxel_layer/lib:/home/peera/voidwalking/ros2_ws/install/rviz_satellite/lib:/home/peera/voidwalking/ros2_ws/install/mapping/lib:/usr/lib/x86_64-linux-gnu/gazebo-11/plugins:/opt/ros/humble/opt/rviz_ogre_vendor/lib:/opt/ros/humble/lib/x86_64-linux-gnu:/opt/ros/humble/lib
# 2025-11-22 10:48:35.412326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TensorFlow version: 2.11.0
# Python version: 3.10.12

# %% [markdown]
# ## Prepare Data

# %%
# Load and preview the dataset

df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Assign model features and the target label column to variables

model_features = df.columns.drop('Class')
X = df[model_features]
y = df['Class']

# %%
# Standadize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# View the target label distribution

y.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# View the number of rows and columns of model features

X_scaled.shape
# Out:
# (284807, 30)

# %% [markdown]
# ## Train a Model

# %%
# Set the contamination and epochs. Contamination ranges between 0 and 0.5 with 0.1 as default value.

contamination = 0.05 
epochs = 30

# %%
# Set the number of neurons per hidden layers

hn = [128, 64, 32, 64, 128]

# Instantiate AutoEncoder and start training

clf = AutoEncoder(epoch_num=epochs, contamination=contamination, hidden_neuron_list=hn)
clf.fit(X_scaled)
# Out:
# Training: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [20:24<00:00, 40.81s/it]

# %% [markdown]
# ## Identify Outliers

# %%
# Obtain prediction on outliers

outliers = clf.predict(X_scaled)

# %%
# Filter outliers

anomaly = np.where(outliers==1)
anomaly
# Out:
# (array([     7,     18,     51, ..., 284772, 284795, 284802]),)

# %%
# Predict a test instance

sample = X.iloc[[4920]]

clf.predict(sample, return_confidence=False)
# Out:
# array([1])

# %%
X.iloc[[4920]]
# Out:
#         Time       V1        V2        V3        V4        V5        V6  \
# 4920  4462.0 -2.30335  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#            V7        V8        V9  ...       V20       V21       V22  \
# 4920  0.56232 -0.399147 -0.238253  ... -0.430022 -0.294166 -0.932391
#
#            V23      V24       V25       V26       V27       V28  Amount
# 4920  0.172726 -0.08733 -0.156114 -0.542628  0.039566 -0.153029  239.93
#
# [1 rows x 30 columns]

# %%
y.iloc[[4920]]
# Out:
# 4920    1
# Name: Class, dtype: int64

# %%
# Ground truth fraudulent transactions

df.loc[df['Class'] == 1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 541    -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623     0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 541     0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623    -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108   -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329   -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
# ...          ...       ...       ...       ...       ...     ...    ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
# Show model's confidence if trained using perturbed data

clf.predict_confidence(sample)
# Out:
# array([1.])

# %%
# Generate binary labels of the training data. 0 means inliers and 1 means outliers

y_pred = clf.labels_  

# Calculate outlier scores of the training data. Higher scores means higher severity of abnormalities

y_scores = clf.decision_scores_

# %%
y_pred[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_scores[:5]
# Out:
# array([2.8285766, 2.2021952, 4.113962 , 3.283342 , 3.6585574],
#       dtype=float32)

# %% [markdown]
# ## Evaluate Model

# %%
# Visualize auto-calculated anomaly scores. Red horizontal line represents threshold.

plt.rcParams["figure.figsize"] = (15,8)
plt.plot(y_scores);
plt.axhline(y=clf.threshold_, c='r', ls='dotted', label='threshold');
plt.xlabel('Instances')
plt.ylabel('Anomaly Scores')
plt.title('Anomaly Scores with Auto-Calculated Threshold');
plt.show()

# %%
# Modify the threshold and view the new distribution. Red horizontal line represents the manually changed threshold.

threshold = 50
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(y_scores, color="green");
plt.axhline(y=threshold, c='r', ls='dotted', label='threshold');
plt.xlabel('Instances')
plt.ylabel('Anomaly Scores')
plt.title('Anomaly Scores with Modified Threshold');
plt.show()

# %%
# Visualize a scatter plot

sns.scatterplot(x="Time", y="Amount", hue=y_scores, data=df, palette="RdBu_r", size=y_scores);
plt.xlabel('Time (seconds elapsed from first transaction)')
plt.ylabel('Amount')
plt.legend(title='Anomaly Scores')
plt.show()
